# %%
"""
HPC 3 cut graphs analysis (space = um)

Keeps:
- Per-box analysis
- Per-box CSVs: summary, bc_faces, density (if available)
- ONE global comparison CSV (summary)
- Global figures:
    * Diameter/length overlays per type (+ optional boxplots)
    * Density:
        - CutBox: 10 µm slabs -> boxplot per CutBox
        - Hippocampus ROI (FULL graph): 50 µm slabs -> vs relative depth (0→1)
    * Shortest A→V path length: overlay hist + boxplot
    * BC cube-net comparison (per face, per box)
    * HDN depth distribution (relative 0→1)
    * Shortest path length ECDF + medians
    * Edge-disjoint A→V bar plot

Removes (per your request):
- V comparison across boxes
- E comparison across boxes
- Edge type composition plots (stacked counts, pies, stacked %)
- HDN pies per box

Author: Ana Barrio
Date: 23 Feb 2026
"""

import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ---------------------------------------------------------------------
# your analysis toolbox
# ---------------------------------------------------------------------
sys.path.insert(0, "/home/admin/Ana/MicroBrain/codes/Graph Analysis & by region/Graph analysis")
from graph_analysis_functions import *

# ---------------------------------------------------------------------
# paths / params
# ---------------------------------------------------------------------
out_root = "/home/admin/Ana/MicroBrain/output/HPC_FULL_ANALYSIS"
os.makedirs(out_root, exist_ok=True)

PATH_FULL = "/home/admin/Ana/MicroBrain/output/um/graph_18_OutGeom_um.pkl"  # whole brain graph with ALL vertices/edges (no cut)

PATHS = {
    "HPC_1": "/home/admin/Ana/MicroBrain/output/um/graph_18_OutGeom_Hcut1_um.pkl",
    "HPC_2": "/home/admin/Ana/MicroBrain/output/um/graph_18_OutGeom_Hcut2_um.pkl",
    "HPC_3": "/home/admin/Ana/MicroBrain/output/um/graph_18_OutGeom_Hcut3_um.pkl",
}

HIPPO_CENTERS = [
    [1200, 3400, 1500],
    [1400, 3900,  950],
    [2100, 4100,  750],
]

box_size_um = (400, 400, 400)
degree_thr  = 4
eps_vox     = 2.0

# Density settings
slab_um_cutbox = 10.0   # CutBox 
slab_um_roi    = 50.0   # ROI depth profile (FULL)
slab_axis      = "z"    # axis used to slab (coordinate axis)

# ROI selection settings (for hippocampus) on FULL graph
ROI_REGION_ATTR = "region"            # vertex attribute name on FULL graph
ROI_LABEL       = "HPC"               # label value in that attribute
ROI_COORDS_ATTR = "coords_image_R"    # coords in um
ROI_MARGIN_UM   = 20.0
FLIP_DEPTH01    = False               # set True if your axis direction is reversed

# plotting controls
plot_paths_cap = 15
bins_hist = 40

BOX_ORDER = list(PATHS.keys())

V_COL = {
    "arteriole": "#d62728",
    "venule":    "#1f77b4",
    "capillary": "#7f7f7f",
    "unknown":   "#c7c7c7",
}
BOX_COL = {
    "HPC_1": "tab:blue",
    "HPC_2": "tab:orange",
    "HPC_3": "tab:green",
}

FACE_ORDER = ["x_min","x_max","y_min","y_max","z_min","z_max"]
FACE_GRID = [
    ["y_max", "z_max", "y_min"],
    ["x_min", "z_min", "x_max"],
]

# ---------------------------------------------------------------------
# helpers
# ---------------------------------------------------------------------
def safe_arr(x, dtype=float):
    return np.asarray(x, dtype=dtype)

def safe_finite(x):
    x = safe_arr(x, float)
    return x[np.isfinite(x)]

def ecdf_xy(x):
    x = safe_finite(x)
    if x.size == 0:
        return np.array([]), np.array([])
    x = np.sort(x)
    y = np.arange(1, x.size + 1) / x.size
    return x, y

def plot_boxplot_by_graph(df_long, value_col, title, ylabel, graphs_order=("HPC_1","HPC_2","HPC_3")):
    groups, labels = [], []
    for g in graphs_order:
        if g not in df_long["graph"].unique():
            continue
        x = df_long.loc[df_long["graph"] == g, value_col].to_numpy(float)
        x = x[np.isfinite(x)]
        groups.append(x)
        labels.append(g)

    plt.figure(figsize=(7, 5))
    plt.boxplot(groups, labels=labels, showfliers=False)
    plt.title(title)
    plt.ylabel(ylabel)
    plt.grid(alpha=0.25, axis="y")
    plt.tight_layout()
    plt.show()

def plot_hist_overlay(df_long, value_col, title, xlabel, bins=40, graphs_order=("HPC_1","HPC_2","HPC_3")):
    plt.figure(figsize=(8, 5))
    for g in graphs_order:
        if g not in df_long["graph"].unique():
            continue
        x = df_long.loc[df_long["graph"] == g, value_col].to_numpy(float)
        x = x[np.isfinite(x)]
        if x.size:
            plt.hist(x, bins=bins, density=True, alpha=0.45, label=g)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel("Density")
    plt.grid(alpha=0.25)
    plt.legend()
    plt.tight_layout()
    plt.show()

def diameter_length_overlay_by_type(dl, bins=40, graphs_order=("HPC_1","HPC_2","HPC_3"), box_label=""):
    for t in sorted(dl["type"].unique()):
        sub = dl[dl["type"] == t].copy()
        fig, axes = plt.subplots(1, 2, figsize=(12, 4))
        fig.suptitle(f"{t} | Diameter & Length distributions | {box_label}", fontsize=12, fontweight="bold")

        ax = axes[0]
        for g in graphs_order:
            x = sub.loc[sub["graph"] == g, "diameter_um"].to_numpy(float)
            x = x[np.isfinite(x)]
            if x.size:
                ax.hist(x, bins=bins, density=True, alpha=0.45, label=g)
        ax.set_title("Diameter")
        ax.set_xlabel("µm")
        ax.set_ylabel("Density")
        ax.grid(alpha=0.25)
        ax.legend()

        ax = axes[1]
        for g in graphs_order:
            x = sub.loc[sub["graph"] == g, "length_um"].to_numpy(float)
            x = x[np.isfinite(x)]
            if x.size:
                ax.hist(x, bins=bins, density=True, alpha=0.45, label=g)
        ax.set_title("Length")
        ax.set_xlabel("µm")
        ax.set_ylabel("Density")
        ax.grid(alpha=0.25)
        ax.legend()

        plt.tight_layout()
        plt.show()

def box_from_points_um(P, margin_um=0.0):
    P = np.asarray(P, float)
    if P.size == 0:
        raise ValueError("No points provided to build ROI box.")
    mins = P.min(axis=0) - float(margin_um)
    maxs = P.max(axis=0) + float(margin_um)
    return {
        "xmin": float(mins[0]), "xmax": float(maxs[0]),
        "ymin": float(mins[1]), "ymax": float(maxs[1]),
        "zmin": float(mins[2]), "zmax": float(maxs[2]),
    }

def compute_roi_box_from_region_attr(G, region_attr, label_value, coords_attr, margin_um=0.0):
    if region_attr not in G.vs.attributes():
        raise KeyError(f"Vertex attr '{region_attr}' not found. Available: {G.vs.attributes()}")
    if coords_attr not in G.vs.attributes():
        raise KeyError(f"Vertex attr '{coords_attr}' not found. Available: {G.vs.attributes()}")

    P = np.asarray(G.vs[coords_attr], float)
    reg = np.array(G.vs[region_attr])
    m = (reg == label_value)
    if not np.any(m):
        top = pd.Series(reg).value_counts().head(10)
        raise ValueError(f"No vertices with {region_attr}=='{label_value}'. Top labels:\n{top}")
    return box_from_points_um(P[m], margin_um=margin_um)
'''
# ---------------------------------------------------------------------
# >>> LOAD FULL GRAPH ONCE (for ROI depth density) <<<
# ---------------------------------------------------------------------
print("\n======================")
print("Loading FULL graph for hippocampus ROI depth density:")
print("  ", PATH_FULL)

data_full = load_data(PATH_FULL)
sync_vertex_attributes_safe(data_full, space="um")
_, _, data_full = single_connected_component(data_full)
G_full_whole = data_full["graph"]

# microsegments from FULL graph (used for ROI depth profile)
ms_full = microsegments(data_full, space="um")

# hippocampus ROI box from FULL graph labels
roi_box_whole = compute_roi_box_from_region_attr(
    G_full_whole,
    region_attr=ROI_REGION_ATTR,
    label_value=ROI_LABEL,
    coords_attr=ROI_COORDS_ATTR,
    margin_um=ROI_MARGIN_UM
)
validate_box_faces(roi_box_whole)

print("FULL hippocampus ROI box:", roi_box_whole)
'''
# ---------------------------------------------------------------------
# COLLECTORS for global outputs
# ---------------------------------------------------------------------
all_summaries   = []
diam_long_parts = []
path_len_rows   = []
bc_rows         = []
hdn_nodes_rows  = []
red_rows        = []

# Density collectors:
# ROI-by-depth (computed from FULL graph, but we store a curve per cut name for convenience)
density_roi_curves = {}   # name -> (pos01, y_roi%)
density_roi_slabs  = {}   # name -> df_roi

# CutBox heterogeneity (computed per cut)
density_box_values = {}   # name -> y_box% vector
density_box_slabs  = {}   # name -> df_box
density_long_rows  = []   # long format: graph, slab_vol_frac_pct

# ---------------------------------------------------------------------
# analysis loop (CUT BOXES)
# ---------------------------------------------------------------------
for (name, path), center in zip(PATHS.items(), HIPPO_CENTERS):
    print("\n======================")
    print("Analyzing:", name)

    data = load_data(path)
    sync_vertex_attributes_safe(data, space="um")
    _, _, data = single_connected_component(data)
    G = data["graph"]

    # CutBox (in um)
    cut_box = make_box_in_um(center, box_size_um, res_um_per_vox=res_um_per_vox)
    validate_box_faces(cut_box)
    '''
    # Subgraph inside CutBox
    G, sub_to_orig, _ = induced_subgraph_box(
        G_full, cut_box,
        coords_attr="coords_image_R",
        node_eps=0.0,
        edge_mode="both"
    )
    '''
    

    # --- Basic stats
    dup = duplicated_edge_stats(G)
    loops = loop_edge_stats(G)

    # --- Lengths / diameters by type (kept)
    nk_u, avg_len = get_avg_length_nkind(G, space="um")
    avg_len_by_type = {EDGE_NKIND_TO_LABEL.get(int(k), str(k)): float(v) for k, v in zip(nk_u, avg_len)}
    diam_stats = diameter_stats_nkind(G, label_dict=EDGE_NKIND_TO_LABEL, plot=True, title_suffix=name)

    # --- per-edge diameter/length (for global overlays)
    length_attr = resolve_length_attr(space="um")
    diam = safe_arr(G.es["diameter"], float)
    leng = safe_arr(G.es[length_attr], float)
    nk   = safe_arr(G.es["nkind"], int)

    for k in np.unique(nk):
        lab = EDGE_NKIND_TO_LABEL.get(int(k), str(k))
        m = (nk == k)
        if np.any(m):
            diam_long_parts.append(pd.DataFrame({
                "graph": name,
                "type": str(lab),
                "diameter_um": diam[m],
                "length_um": leng[m],
            }))

    # per-box length distribution by type (kept)
    plot_hist_by_category_general(
        values=safe_arr(G.es[length_attr], float),
        category=safe_arr(G.es["nkind"], int),
        label_dict=EDGE_NKIND_TO_LABEL,
        bins=bins_hist,
        layout="horizontal",
        density=True,
        show_mean=True,
        variable_name="Edge length (µm)",
        category_name="Vessel type",
        main_title=f"Length distribution by vessel type | {name}"
    )

    # --- HDN analysis (kept)
    get_degrees(G, threshold=degree_thr)

    hdn = analyze_hdn_pattern_in_box(
        G, space="um",
        coords_attr="coords_image_R",
        degree_thr=degree_thr,
        box=cut_box,
        eps_vox=eps_vox
    )

    deg = safe_arr(G.degree(), int)
    hdn_nodes = np.where(deg >= degree_thr)[0]
    coords = np.asarray(G.vs["coords_image_R"], float)

    for v in hdn_nodes:
        t = infer_node_type_from_incident_edges(G, int(v))
        x, y, z = coords[int(v)]
        hdn_nodes_rows.append({
            "graph": name,
            "v": int(v),
            "x": float(x), "y": float(y), "z": float(z),
            "degree": int(deg[int(v)]),
            "type": t
        })

    plot_degree_nodes_spatial(
        G,
        space="um",
        coords_attr="coords_image_R",
        degree_min=degree_thr,
        degree_max=None,
        by_type=True,
        title=f"High-degree nodes (deg ≥ {degree_thr}) | {name}"
    )

    # --- BC faces (kept)
    bc = analyze_bc_faces(
        G, cut_box,
        space="um",
        coords_attr="coords_image_R",
        eps=eps_vox,
        degree_thr=degree_thr
    )

    bc_df = bc_faces_table(bc, box_name=name).copy()
    bc_df["graph"] = name

    # Convert % -> counts per type (for global cube-net stacked bars)
    for vname, pcol in {
        "arteriole": "% Arteriole",
        "venule": "% Venule",
        "capillary": "% Capillary",
        "unknown": "% Unknown",
    }.items():
        bc_df[f"n_{vname}"] = (
            pd.to_numeric(bc_df["BC nodes"], errors="coerce").fillna(0.0) *
            pd.to_numeric(bc_df[pcol], errors="coerce").fillna(0.0) / 100.0
        )

    bc_rows.append(bc_df)

    plot_bc_cube_net(bc, title=f"BC composition per face (cube net) | {name}")
    plot_bc_3_cubes_tinted(G, cut_box, space="um", coords_attr="coords_image_R", eps=eps_vox)

    # --- Redundancy: ALL shortest A->V paths (count ALL; plot limited)
    groups = nodes_by_label(G)
    A = np.asarray(groups.get("arteriole", []), dtype=int)
    V = np.asarray(groups.get("venule", []), dtype=int)

    shortest_paths = []
    if A.size and V.size:
        for a in A:
            for v in V:
                p = G.get_shortest_paths(int(a), to=int(v))[0]
                if len(p) > 1:
                    shortest_paths.append(p)

    for p in shortest_paths:
        path_len_rows.append({"graph": name, "path_len_edges": int(len(p) - 1)})

    if shortest_paths:
        plot_av_paths_in_box(
            G, cut_box,
            shortest_paths[:plot_paths_cap],
            space="um",
            coords_attr="coords_image_R",
            node_eps=0.0
        )
    '''
    # -----------------------------------------------------------------
    # Vessel density:
    #   A) ROI density vs depth from FULL graph (same curve for all cuts; we store once per name)
    #   B) CutBox heterogeneity from each CUT graph
    # -----------------------------------------------------------------

    # A) ROI density vs depth (FULL)
    try:
        df_roi = vessel_vol_frac_slabs_in_box(ms_full, roi_box_whole, slab=slab_um_roi, axis=slab_axis)
        density_roi_slabs[name] = df_roi.copy()

        mid_roi = 0.5 * (df_roi["slab_lo"].to_numpy(float) + df_roi["slab_hi"].to_numpy(float))
        y_roi   = df_roi["total_vol_frac"].to_numpy(float) * 100.0

        dmin = float({"x": roi_box_whole["xmin"], "y": roi_box_whole["ymin"], "z": roi_box_whole["zmin"]}[slab_axis])
        dmax = float({"x": roi_box_whole["xmax"], "y": roi_box_whole["ymax"], "z": roi_box_whole["zmax"]}[slab_axis])
        pos01 = (mid_roi - dmin) / (dmax - dmin) if dmax > dmin else np.full_like(mid_roi, np.nan)

        if FLIP_DEPTH01:
            pos01 = 1.0 - pos01

        density_roi_curves[name] = (pos01, y_roi)

        df_roi.to_csv(os.path.join(out_root, f"{name}_ROI_FULL_density_slabs_{int(slab_um_roi)}um.csv"), index=False)

    except Exception as e:
        print(f"[{name}] ROI(FULL) density failed:", e)
    '''

    # B) CutBox heterogeneity (CUT graph)
    density_mean_cutbox = np.nan
    try:
        ms_cut = microsegments(data, space="um")
        df_box = vessel_vol_frac_slabs_in_box(ms_cut, cut_box, slab=slab_um_cutbox, axis=slab_axis)
        density_box_slabs[name] = df_box.copy()

        y_box = df_box["total_vol_frac"].to_numpy(float) * 100.0
        density_box_values[name] = y_box
        density_mean_cutbox = float(np.nanmean(y_box))

        for v in y_box:
            density_long_rows.append({"graph": name, "slab_vol_frac_pct": float(v)})

        df_box.to_csv(os.path.join(out_root, f"{name}_CutBox_density_slabs_{int(slab_um_cutbox)}um.csv"), index=False)

    except Exception as e:
        print(f"[{name}] cut-box density failed:", e)

    # --- Distance to surface (kept)
    d2s_mean = np.nan
    d2s_median = np.nan
    if "distance_to_surface_R" in G.vs.attributes():
        nodes = np.arange(G.vcount())
        d2s = distance_to_surface_stats(G, nodes, space="um")
        d2s_mean = float(d2s["mean"])
        d2s_median = float(d2s["median"])

    # --- Edge-disjoint paths (maxflow) (kept)
    red = max_edge_disjoint_av(G)
    n_disjoint = int(red["n_edge_disjoint_av"])
    nA = int(red["nA"])
    nV = int(red["nV"])

    red_rows.append({
        "graph": name,
        "edge_disjoint_AV": n_disjoint,
        "A_nodes": nA,
        "V_nodes": nV,
        "shortest_paths_n": int(len(shortest_paths)),
        "shortest_path_len_median": float(np.median([len(p)-1 for p in shortest_paths])) if shortest_paths else np.nan,
        "shortest_path_len_p90": float(np.percentile([len(p)-1 for p in shortest_paths], 90)) if shortest_paths else np.nan,
    })

    # --- Summary row (density_mean is CutBox mean here)
    summary = {
        "graph": name,
        "V": int(G.vcount()),
        "E": int(G.ecount()),
        "dup_%": float(dup["perc_extra_edges"]),
        "loops_%": float(loops["perc_loops"]),
        "HDN_n": int(hdn.get("n_hdn", 0)),
        "HDN_frac": float(hdn.get("hdn_fraction", 0.0)),
        "shortest_paths_n": int(len(shortest_paths)),
        "edge_disjoint_AV": int(n_disjoint),
        "A_nodes": int(nA),
        "V_nodes": int(nV),
        "density_mean_cutbox_%": float(density_mean_cutbox) if np.isfinite(density_mean_cutbox) else np.nan,
        "d2s_mean": float(d2s_mean) if np.isfinite(d2s_mean) else np.nan,
        "d2s_median": float(d2s_median) if np.isfinite(d2s_median) else np.nan,
    }

    # - avg length by type
    for nm, val in avg_len_by_type.items():
        summary[f"avg_len_{nm}_um"] = float(val)

    # - diameter by type
    for _, st in diam_stats.items():
        nm = st["name"]
        summary[f"diam_mean_{nm}_um"] = float(st["mean"])
        summary[f"diam_median_{nm}_um"] = float(st["median"])
        summary[f"diam_p5_{nm}_um"] = float(st["p5"])
        summary[f"diam_p95_{nm}_um"] = float(st["p95"])

    all_summaries.append(summary)

    # save per-box CSVs
    pd.DataFrame([summary]).to_csv(os.path.join(out_root, f"{name}_summary.csv"), index=False)
    bc_df.to_csv(os.path.join(out_root, f"{name}_bc_faces.csv"), index=False)

# ---------------------------------------------------------------------
# Store summary
# ---------------------------------------------------------------------
summary_df = pd.DataFrame(all_summaries)
summary_csv = os.path.join(out_root, "HPC_summary_COMPARISON.csv")
summary_df.to_csv(summary_csv, index=False)
print("\nSaved:", summary_csv)

# =====================================================================
# GLOBAL FIGURES (kept)
# =====================================================================
BOX_LABEL = " vs ".join(BOX_ORDER)

# Diameter/Length distributions per type
if diam_long_parts:
    dl = pd.concat(diam_long_parts, ignore_index=True)
    dl["type"] = dl["type"].astype(str)

    diameter_length_overlay_by_type(dl, bins=bins_hist, box_label=BOX_LABEL)

    # optional boxplots
    for t in sorted(dl["type"].unique()):
        sub = dl[dl["type"] == t].copy()
        plot_boxplot_by_graph(sub, "diameter_um", title=f"Diameter boxplot | type={t}", ylabel="Diameter (µm)")
        plot_boxplot_by_graph(sub, "length_um", title=f"Length boxplot | type={t}", ylabel="Length (µm)")

# ---------------------------------------------------------------------
# Density GLOBAL FIGURES
# ---------------------------------------------------------------------

# 1) ROI density vs depth (FULL) overlay (x = relative depth 0→1)
# NOTE: the curves will be identical across names because ROI is from the same FULL graph.
#       Keeping it this way preserves your existing "3 curves combined" interface.
if density_roi_curves:
    plt.figure(figsize=(8, 5))
    for name, (x, y) in density_roi_curves.items():
        plt.plot(x, y, marker="o", label=name, color=BOX_COL.get(name, None))
    plt.xlabel("Relative depth (0→1)" + (" [flipped]" if FLIP_DEPTH01 else ""))
    plt.ylabel("Vessel volume fraction (%)")
    plt.title(f"Hippocampus ROI density vs depth (FULL) | slab={int(slab_um_roi)} µm")
    plt.grid(alpha=0.25)
    plt.legend()
    plt.tight_layout()
    plt.show()

# 2) CutBox density heterogeneity (10 µm) -> boxplot per CutBox
if density_box_values:
    order = [g for g in BOX_ORDER if g in density_box_values]
    groups = [safe_finite(density_box_values[g]) for g in order]

    plt.figure(figsize=(7, 5))
    plt.boxplot(groups, labels=order, showfliers=False)
    plt.title(f"CutBox vessel density heterogeneity | slab={int(slab_um_cutbox)} µm | {BOX_LABEL}")
    plt.ylabel("Vessel volume fraction per slab (%)")
    plt.grid(alpha=0.25, axis="y")
    plt.tight_layout()
    plt.show()

    pd.DataFrame(density_long_rows).to_csv(
        os.path.join(out_root, f"CutBox_density_long_{int(slab_um_cutbox)}um.csv"),
        index=False
    )

# Shortest path length distribution (#edges): overlay hist + boxplot
if path_len_rows:
    pldf = pd.DataFrame(path_len_rows)

    plot_hist_overlay(
        pldf, "path_len_edges",
        title=f"Shortest A→V path length (#edges) | {BOX_LABEL}",
        xlabel="Path length (#edges)",
        bins=30,
    )
    plot_boxplot_by_graph(
        pldf, "path_len_edges",
        title=f"Shortest A→V path length (#edges) | {BOX_LABEL}",
        ylabel="Path length (#edges)",
    )

print("\nGLOBAL figures generated in:", out_root)

# ---------------------------------------------------------------------
# BC cube-net compare (per face, per box, stacked by vessel type)
# ---------------------------------------------------------------------
if len(bc_rows) == 0:
    print("[BC] bc_rows is empty -> nothing to plot.")
else:
    bc_all = pd.concat(bc_rows, ignore_index=True)

    face_col = "Face" if "Face" in bc_all.columns else ("face" if "face" in bc_all.columns else None)
    if face_col is None:
        print("[BC] Could not find face column ('Face' or 'face') in bc_all.")
    else:
        COLMAP = {
            "arteriole": "n_arteriole",
            "venule": "n_venule",
            "capillary": "n_capillary",
            "unknown": "n_unknown",
        }
        total_col = "BC nodes" if "BC nodes" in bc_all.columns else None

        for col in list(COLMAP.values()) + ([total_col] if total_col else []):
            if col not in bc_all.columns:
                bc_all[col] = 0.0
            bc_all[col] = pd.to_numeric(bc_all[col], errors="coerce").fillna(0.0)

        fig, axes = plt.subplots(2, 3, figsize=(13, 7), sharey=True)
        fig.suptitle(f"Boundary conditions | cube-net compare | {BOX_LABEL}", fontsize=14)

        for r in range(2):
            for c in range(3):
                face = FACE_GRID[r][c]
                ax = axes[r, c]
                sub = bc_all.loc[bc_all[face_col] == face].copy()

                if sub.empty:
                    ax.set_title(face)
                    ax.text(0.5, 0.5, "no data", ha="center", va="center")
                    ax.set_xticks([])
                    ax.set_yticks([])
                    continue

                group_cols = list(COLMAP.values()) + ([total_col] if total_col else [])
                sub = sub.groupby("graph", as_index=False)[group_cols].sum()

                x = np.arange(len(BOX_ORDER))
                bottom = np.zeros(len(BOX_ORDER), float)

                for vname in ["arteriole", "venule", "capillary", "unknown"]:
                    col = COLMAP[vname]
                    vals = np.array([
                        float(sub.loc[sub["graph"] == g, col].iloc[0]) if (sub["graph"] == g).any() else 0.0
                        for g in BOX_ORDER
                    ], dtype=float)

                    ax.bar(x, vals, bottom=bottom, label=vname, color=V_COL.get(vname, "lightgrey"))
                    bottom += vals

                if total_col and total_col in sub.columns:
                    tot = np.array([
                        float(sub.loc[sub["graph"] == g, total_col].iloc[0]) if (sub["graph"] == g).any() else 0.0
                        for g in BOX_ORDER
                    ], dtype=float)
                    ax.plot(x, tot, "k.", markersize=8, label="total" if (r == 0 and c == 0) else None)

                ax.set_title(face)
                ax.set_xticks(x)
                ax.set_xticklabels(BOX_ORDER)
                ax.grid(alpha=0.25, axis="y")

        handles, labels = axes[0, 0].get_legend_handles_labels()
        fig.legend(handles, labels, loc="lower center", ncol=5, frameon=False)
        plt.tight_layout(rect=[0, 0.06, 1, 0.95])
        plt.show()

# ---------------------------------------------------------------------
# Redundancy: shortest path length ECDF + medians
# ---------------------------------------------------------------------
if path_len_rows:
    sp = pd.DataFrame(path_len_rows)

    plt.figure(figsize=(7.5, 5))
    for g in BOX_ORDER:
        x = sp.loc[sp["graph"] == g, "path_len_edges"].to_numpy(float)
        x = x[np.isfinite(x)]
        if not x.size:
            continue
        xs, ys = ecdf_xy(x)
        plt.plot(xs, ys, label=g, color=BOX_COL.get(g, None))
        plt.axvline(float(np.median(xs)), color=BOX_COL.get(g, None), linestyle="--", alpha=0.8)

    plt.title(f"Shortest A→V path length (ECDF) | {BOX_LABEL}")
    plt.xlabel("Path length (#edges)")
    plt.ylabel("ECDF")
    plt.grid(alpha=0.25)
    plt.legend()
    plt.tight_layout()
    plt.show()

# ---------------------------------------------------------------------
# Edge-disjoint (maxflow) as bars
# ---------------------------------------------------------------------
if red_rows:
    ed = pd.DataFrame(red_rows).set_index("graph").reindex(BOX_ORDER)

    plt.figure(figsize=(6.5, 4.5))
    plt.bar(BOX_ORDER, ed["edge_disjoint_AV"].to_numpy(float))
    plt.title(f"Edge-disjoint A→V paths (maxflow) | {BOX_LABEL}")
    plt.ylabel("# edge-disjoint paths")
    plt.grid(alpha=0.25, axis="y")
    plt.tight_layout()
    plt.show()
# Out:
# ...
# Analyzing: HPC_1
# [sync_vertex_attributes_safe] copied 3 attrs: ['coords_image_R', 'radii_atlas_R', 'distance_to_surface_R']
# The graph has 12 components. Keeping the largest one.
#
# === GIANT COMPONENT ===
# Original: 720 V 799 E
# Giant   : 659 V 748 E
#
# Average length by nkind (space=um):
#
# nkind = 2: average length (length_R) = 229.633955 µm
# nkind = 4: average length (length_R) = 225.588328 µm
# arteriole (nkind=2, n=27):
#   mean:   7.26 µm
#   median: 7.21 µm
#   p5–p95: 4.47 – 10.27 µm
#
# capillary (nkind=4, n=721):
#   mean:   6.30 µm
#   median: 6.00 µm
#   p5–p95: 4.90 – 7.48 µm
# Unique degrees: [1 2 3 4 5]
# HDN (>= 4): 34
# === Volume fraction slabs (axis=z, slab=10.0 µm) ===
#     slab_lo  slab_hi  tissue_vol  total_vol_frac  arteriole_vol_frac  \
# 0    3550.0   3560.0   1600000.0        0.030213            0.000000
# 1    3560.0   3570.0   1600000.0        0.034333            0.000000
# 2    3570.0   3580.0   1600000.0        0.051255            0.003260
# ...

# %%
import pickle
# Load graph
with open("/home/admin/Ana/MicroBrain/MVN1_corrected_SI.pkl", "rb") as f:
    G = pickle.load(f, encoding='latin1')

print(G.vs.attributes())
print(G.es.attributes())

import pickle
# Load graph
with open("/home/admin/Ana/MicroBrain/output/vox_gaia/graph_18_OutGeom_Hcut1_vox_gaia.pkl", "rb") as f:
    G1 = pickle.load(f, encoding='latin1')
print(G1.vs.attributes())
print(G1.es.attributes())
# Out:
# /tmp/ipykernel_8401/1575827330.py:4: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   G = pickle.load(f, encoding='latin1')
# ['index', 'coords', 'pBC', 'pressure', 'border_vertices', 'boundaryType', 'boundaryValue']
# ['diameters', 'htt', 'nkind', 'lengths', 'diameter', 'connectivity', 'length', 'points', 'lengths2']
# ['coords', 'index', 'annotation', 'diameter']
# ['geom_start', 'geom_end', 'nkind', 'length', 'diameter', 'connectivity', 'points', 'lengths2', 'diameters']

# %%
import numpy as np

# --- edge geometry indices ---
start_idx = np.asarray(G.es["geom_start"], dtype=int)
end_idx   = np.asarray(G.es["geom_end"], dtype=int)

# --- eps (IMPORTANTE: mismo eps que en analyze_bc_faces) ---
eps_face = resolve_eps(2.0, space="um", axis=0)   # o el eps que uses

    # CutBox (in um)
cut_box = make_box_in_um(center, box_size_um, res_um_per_vox=res_um_per_vox)
validate_box_faces(cut_box)

# --- box ---
value = float(cut_box["ymin"])   # cara y_min

with open("/home/admin/Ana/MicroBrain/output/um/graph_18_OutGeom_Hcut1_um.pkl", "rb") as f:
    data = pickle.load(f, encoding='latin1')
G = data["graph"]
geom = data["geom_R"]

AXIS_IDX = {"x": 0, "y": 1, "z": 2}
y_geom = np.asarray(geom["y_R"], dtype=float) 

def edges_touch_or_cross_face_from_geom(G, geom_coord, start_idx, end_idx, value, eps):
    touched = []
    for e in range(G.ecount()):
        s = int(start_idx[e])
        en = int(end_idx[e])
        if en - s < 2:
            continue

        seg = geom_coord[s:en]

        # touch within eps
        if np.any(np.abs(seg - value) <= eps):
            touched.append(e)
            continue

        # cross plane
        d = seg - value
        if np.any(d[:-1] * d[1:] < 0):
            touched.append(e)

    return np.asarray(touched, dtype=int)
edges_crossing_ymin = edges_touch_or_cross_face_from_geom(
    G,
    y_geom,
    start_idx,
    end_idx,
    value,
    eps_face
)
print("Edges touching/crossing y_min:", len(edges_crossing_ymin))
# Out:
# Edges touching/crossing y_min: 0
# /tmp/ipykernel_34955/2891790886.py:18: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data = pickle.load(f, encoding='latin1')

# %%
# -------------------------
# 5) DENSITY SLABS COMPARISON DONE RIGHT:
#    plot vs RELATIVE DEPTH (0→1) so boxes align
# -------------------------
if len(density_df):
    plt.figure(figsize=(7,5))
    for g in BOX_ORDER:
        if g not in density_slabs:
            continue
        dfden = density_slabs[g]
        mid = 0.5 * (dfden["slab_lo"].to_numpy(dtype=float) + dfden["slab_hi"].to_numpy(dtype=float))
        vol = dfden["total_vol_frac"].to_numpy(dtype=float)

        # convert to relative depth so curves align
        zmin = float(np.min(mid))
        zmax = float(np.max(mid))
        if zmax > zmin:
            zrel = (mid - zmin) / (zmax - zmin)
        else:
            zrel = mid * 0.0

        plt.plot(vol, zrel, marker="o", label=g)

    plt.ylabel("Relative depth in box (0→1)")
    plt.xlabel ("Vessel volume fraction (Vessel Vol / Tissue vol * 100)")
    plt.title(f"Density slabs (aligned) | slab={slab_um_cutbox}µm axis={slab_axis}")
    plt.grid(alpha=0.25)
    plt.legend()
    plt.tight_layout()
    plt.gca().invert_yaxis()
    #savefig(os.path.join(out_root, "COMPARE_density_slabs_relative_depth.png"))
    plt.show()

    plot_density_slabs_relative_depth(
    density_slabs,
    box_order=BOX_ORDER,
    slab_um=slab_um_cutbox,
    slab_axis=slab_axis,
    box_colors=BOX_COL
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 34
#      31     #savefig(os.path.join(out_root, "COMPARE_density_slabs_relative_depth.png"))
#      32     plt.show()
# ---> 34     plot_density_slabs_relative_depth(
#      35     density_slabs,
#      36     box_order=BOX_ORDER,
#      37     slab_um=slab_um,
#      38     slab_axis=slab_axis,
#      39     box_colors=BOX_COL
#      40 )
#
# NameError: name 'plot_density_slabs_relative_depth' is not defined

# %%
# ======================================================
# GLOBAL COMPARISON FIGURES 
# ======================================================

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

BOX_ORDER = list(PATHS.keys())  # ["HPC_1","HPC_2","HPC_3"]

def savefig(path):
    plt.savefig(path, dpi=220, bbox_inches="tight")



# -------------------------
# FIXED TYPE COLORS (semantic)
# -------------------------
TYPE_COLORS = {
    "arteriole": "red",
    "venule": "blue",
    "capillary": "grey",
    "unknown": "black",
}

def plot_pies_with_bars_edge_types(summary_df, out_png=None, box_order=None, type_colors=None):
    """
    For each box (graph), draw:
      - left: bar chart with V, E, and counts per type
      - right: pie of edge type composition (arteriole/venule/capillary)

    Requires in summary_df:
      graph, V, E, E_arteriole, E_venule, E_capillary (optional: E_unknown)
    """
    if box_order is None:
        box_order = BOX_ORDER
    if type_colors is None:
        type_colors = TYPE_COLORS if "TYPE_COLORS" in globals() else {
            "arteriole": "tab:red",
            "venule": "tab:blue",
            "capillary": "tab:gray",
            "unknown": "lightgrey",
        }

    n = len(box_order)
    fig, axes = plt.subplots(
        n, 2, figsize=(10, 3.6 * n),
        gridspec_kw={"width_ratios": [1.4, 1.1]}  # wider bars (left), narrower pie (right)
    )

    # handle n=1 case (matplotlib returns 1d axes sometimes)
    if n == 1:
        axes = np.array([axes])

    for i, g in enumerate(box_order):
        if g not in summary_df["graph"].values:
            axes[i, 0].axis("off")
            axes[i, 1].axis("off")
            continue

        row = summary_df.loc[summary_df["graph"] == g].iloc[0]

        # -------------------
        # LEFT: bars (counts)
        # -------------------
        ax_bar = axes[i, 0]

        bar_labels = ["V", "E", "E_art", "E_ven", "E_cap"]
        bar_values = [
            float(row["V"]) if "V" in summary_df.columns else np.nan,
            float(row["E"]) if "E" in summary_df.columns else np.nan,
            float(row.get("E_arteriole", np.nan)),
            float(row.get("E_venule", np.nan)),
            float(row.get("E_capillary", np.nan)),
        ]

        # Optional unknown
        has_unknown = "E_unknown" in summary_df.columns
        if has_unknown:
            bar_labels.append("E_unk")
            bar_values.append(float(row.get("E_unknown", np.nan)))

        # replace non-finite with 0 for plotting
        bar_values = [v if np.isfinite(v) else 0.0 for v in bar_values]

        # Colors: only type bars colored; V/E neutral
        bar_colors = [
            "lightgrey",  # V
            "lightgrey",  # E
            type_colors.get("arteriole", "tab:red"),
            type_colors.get("venule", "tab:blue"),
            type_colors.get("capillary", "tab:gray"),
        ]
        if has_unknown:
            bar_colors.append(type_colors.get("unknown", "lightgrey"))

        ax_bar.bar(bar_labels, bar_values, color=bar_colors)
        ax_bar.set_title(f"{g} | counts")
        ax_bar.set_ylabel("#")
        ax_bar.grid(alpha=0.25, axis="y")

        ymax = max(bar_values) if bar_values else 1.0
        for x, v in enumerate(bar_values):
            ax_bar.text(x, v + 0.01 * ymax, f"{int(v)}", ha="center", va="bottom", fontsize=9)

        # -------------------
        # RIGHT: pie
        # -------------------
        ax_pie = axes[i, 1]
        labels, vals, cols = [], [], []

        for lab in ["arteriole", "venule", "capillary"]:
            c = f"E_{lab}"
            if c in summary_df.columns and np.isfinite(row[c]) and float(row[c]) > 0:
                labels.append(lab)
                vals.append(float(row[c]))
                cols.append(type_colors.get(lab, "lightgrey"))

        if sum(vals) == 0:
            ax_pie.text(0.5, 0.5, "no data", ha="center", va="center")
        else:
            ax_pie.pie(vals, labels=labels, colors=cols, autopct="%1.1f%%", startangle=90)

        ax_pie.set_title(f"{g} | edge types")

    plt.tight_layout()

    # if out_png is not None:
    #     plt.savefig(out_png, dpi=220, bbox_inches="tight")

    plt.show()

plot_pies_with_bars_edge_types(
    summary_df,
    box_order=BOX_ORDER,
    type_colors=TYPE_COLORS
)



# -------------------------
# 3) ONE FIGURE: DIAMETER + LENGTH ECDF BY TYPE (3 boxes overlay)
#    - fixed: medians per box (colored like the curve)
#    - fixed: consistent colors per box across ALL types (HPC_1 blue, HPC_2 orange, HPC_3 green)
# -------------------------

BOX_ORDER = ["HPC_1", "HPC_2", "HPC_3"]
BOX_COLORS = {
    "HPC_1": "tab:blue",
    "HPC_2": "tab:orange",
    "HPC_3": "tab:green",
}

def ecdf(x):
    x = np.asarray(x, float)
    x = x[np.isfinite(x)]
    if x.size == 0:
        return np.array([]), np.array([])
    x = np.sort(x)
    y = np.arange(1, x.size + 1) / x.size
    return x, y

if len(diam_long_rows):
    dl = pd.concat(diam_long_rows, ignore_index=True)

    # Your dl["type"] values are labels (often 'arteriole','venule','capillary').
    # Keep a stable order if present.
    types = [t for t in ["arteriole", "venule", "capillary"] if t in dl["type"].unique()]
    if not types:
        types = sorted(dl["type"].unique())

    fig, axes = plt.subplots(2, len(types), figsize=(5 * len(types), 7))
    if len(types) == 1:
        axes = np.array([[axes[0]], [axes[1]]])

    for j, t in enumerate(types):

        # -------------------------
        # DIAMETER ECDF + MEDIANS
        # -------------------------
        ax = axes[0, j]
        for g in BOX_ORDER:
            x = dl[(dl["graph"] == g) & (dl["type"] == t)]["diameter_um"].to_numpy(dtype=float)
            x = x[np.isfinite(x)]
            if not x.size:
                continue

            xs, ys = ecdf(x)
            c = BOX_COLORS.get(g, None)

            ax.plot(xs, ys, label=g, color=c)

            med = float(np.median(xs))
            ax.axvline(med, color=c, linestyle="--", alpha=0.85, linewidth=1.5)
            # optional numeric label:
            # ax.text(med, 0.05, f"{med:.1f}", color=c, rotation=90, va="bottom", ha="right", fontsize=8)

        ax.set_title(f"Diameter ECDF | {t}")
        ax.set_xlabel("diameter (µm)")
        ax.set_ylabel("ECDF")
        ax.grid(alpha=0.25)
        ax.legend(fontsize=9)

        # -------------------------
        # LENGTH ECDF + MEDIANS
        # -------------------------
        ax = axes[1, j]
        for g in BOX_ORDER:
            x = dl[(dl["graph"] == g) & (dl["type"] == t)]["length_um"].to_numpy(dtype=float)
            x = x[np.isfinite(x)]
            if not x.size:
                continue

            xs, ys = ecdf(x)
            c = BOX_COLORS.get(g, None)

            ax.plot(xs, ys, label=g, color=c)

            med = float(np.median(xs))
            ax.axvline(med, color=c, linestyle="--", alpha=0.85, linewidth=1.5)
            # optional numeric label:
            # ax.text(med, 0.05, f"{med:.0f}", color=c, rotation=90, va="bottom", ha="right", fontsize=8)

        ax.set_title(f"Length ECDF | {t}")
        ax.set_xlabel("length (µm)")
        ax.set_ylabel("ECDF")
        ax.grid(alpha=0.25)
        ax.legend(fontsize=9)

    plt.tight_layout()
    savefig(os.path.join(out_root, "COMPARE_bytype_ECDF_diam_and_len.png"))
    plt.show()

# -------------------------
# 4) HDN TYPE PIE PER BOX (fixed colors)
#    NOTE: your hdn_df stores percentages already
# -------------------------
def plot_pies_hdn_types(hdn_type_rows, out_png):
    if not len(hdn_type_rows):
        print("No HDN rows.")
        return

    hdn_df = pd.DataFrame(hdn_type_rows).set_index("graph")
    hdn_df = hdn_df.loc[[g for g in BOX_ORDER if g in hdn_df.index]].copy()

    fig, axes = plt.subplots(1, len(hdn_df.index), figsize=(4*len(hdn_df.index), 4))
    if len(hdn_df.index) == 1:
        axes = [axes]

    for ax, g in zip(axes, hdn_df.index):
        labels, vals, cols = [], [], []

        # Prefer % columns
        for lab in ["arteriole", "venule", "capillary", "unknown"]:
            c = f"HDN_{lab}_%"
            if c in hdn_df.columns:
                v = float(hdn_df.loc[g, c])
                if np.isfinite(v) and v > 0:
                    labels.append(lab)
                    vals.append(v)
                    cols.append(TYPE_COLORS.get(lab, "lightgrey"))

        if sum(vals) == 0:
            ax.text(0.5, 0.5, "no HDN", ha="center", va="center")
        else:
            ax.pie(
                vals,
                labels=labels,
                colors=cols,
                autopct="%1.1f%%",
                startangle=90)
        ax.set_title(f"{g} | HDN types (%)")

        ax.set_title(f"{g} | HDN types (%)")

    plt.tight_layout()
    savefig(out_png)
    plt.show()

plot_pies_hdn_types(hdn_type_rows, os.path.join(out_root, "COMPARE_pies_HDN_types.png"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 163
#     160     y = np.arange(1, x.size + 1) / x.size
#     161     return x, y
# --> 163 if len(diam_long_rows):
#     164     dl = pd.concat(diam_long_rows, ignore_index=True)
#     166     # Your dl["type"] values are labels (often 'arteriole','venule','capillary').
#     167     # Keep a stable order if present.
#
# NameError: name 'diam_long_rows' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 # -------------------------
#       2 # 5) DENSITY SLABS COMPARISON DONE RIGHT:
#       3 #    plot vs RELATIVE DEPTH (0→1) so boxes align
#       4 # -------------------------
# ----> 5 if len(density_slabs):
#       6     plt.figure(figsize=(7,5))
#       7     for g in BOX_ORDER:
#
# NameError: name 'density_slabs' is not defined

# %%
import importlib
import numpy as np
import graph_analysis_functions as gaf
import pickle
importlib.reload(gaf)

# %%
EDGE_NKIND_TO_LABEL = {
    2: "arteriole",
    3: "venule",
    4: "capillary"
}

# %%
# --------------------------------------------------------------------------------------
# 1) IMPORT  MODULE 
# --------------------------------------------------------------------------------------
import graph_analysis_functions as gaf  


# --------------------------------------------------------------------------------------
# 2) USER INPUTS 
# --------------------------------------------------------------------------------------
DATA_PATH = "/home/admin/Ana/MicroBrain/output/graph_18_OutGeom_Hcut3_um.pkl"  
SPACE = "um"                        # "vox" or "um"
EPS_VOX = 2.0                        # ALWAYS in voxels (converted internally if SPACE="um")
DEGREE_THR = 4

# Box definition (center_vox from Paraview + size_um)
CENTER_VOX = [2100, 4200, 750]        # <-- from ParaView etc (in vox)
BOX_SIZE_UM = [400, 400, 400]        # <-- physical size

# Image resolution (for vox→µm conversions)
res_um_per_vox = np.array([1.625, 1.625, 2.5]) 

# Gaia density options
DO_GAIA = True
SLAB_UM = 50.0
SLAB_AXIS = "z"

# Redundancy (simple shortest paths)
DO_PATHS = True
K_PATHS = 5


# --------------------------------------------------------------------------------------
# 3) BUILD BOX CONSISTENT WITH SPACE
# --------------------------------------------------------------------------------------
if SPACE == "vox":
    cut_box = gaf.make_box_in_vox(CENTER_VOX, BOX_SIZE_UM, res_um_per_vox=res_um_per_vox)
else:
    cut_box = gaf.make_box_in_um(CENTER_VOX, BOX_SIZE_UM, res_um_per_vox=res_um_per_vox)

gaf.validate_box_faces(cut_box)


# --------------------------------------------------------------------------------------
# 4) LOAD DATA + SYNC ATTRIBUTES
# --------------------------------------------------------------------------------------
data = gaf.load_data(DATA_PATH)            # dict with keys: graph, vertex, geom (+ _R optional)



#data = gaf.sync_vertex_attributes_safe(data, space=SPACE)
G = data["graph"]

# keep only giant component
#_, ncomp, data = gaf.single_connected_component(data)
#G = data["graph"]

#coords_attr = gaf.resolve_coords_attr(space=SPACE)
print("\n=== Graph ===")
print(G.vs.attributes())
print(G.es.attributes())
#print("coords_attr:", coords_attr)
print("box:", box)



# --------------------------------------------------------------------------------------
# 5) CLASSIC QC: DUPLICATES + LOOPS
# --------------------------------------------------------------------------------------
dup_stats = gaf.duplicated_edge_stats(G)
loop_stats = gaf.loop_edge_stats(G)
print("\n=== QC ===")
print("Duplicates:", dup_stats)
print("Loops:", loop_stats)


# --------------------------------------------------------------------------------------
# 6) EDGE TYPES + LENGTH + DIAMETER
# --------------------------------------------------------------------------------------
print("\n=== Edge type composition ===")
edge_types = gaf.get_edges_types(G, label_dict=gaf.EDGE_NKIND_TO_LABEL, return_dict=True)

print("\n=== Mean length by nkind ===")
try:
    gaf.get_avg_length_nkind(G, space=SPACE)
except Exception as e:
    print("Length-by-nkind skipped:", e)

print("\n=== Diameter stats by nkind (+ plot) ===")
try:
    diam_stats = gaf.diameter_stats_nkind(G, label_dict=EDGE_NKIND_TO_LABEL, ranges=None, plot=True)
except Exception as e:
    print("Diameter stats skipped:", e)


# --------------------------------------------------------------------------------------
# 7) DEGREE + HDN SPATIAL PLOTS
# --------------------------------------------------------------------------------------
print("\n=== Degree / HDN ===")
uniq_deg, hdn_idx = gaf.get_degrees(G, threshold=DEGREE_THR)

# Spatial plots 
gaf.plot_degree_nodes_spatial(
    G,
    space=SPACE,
    coords_attr=coords_attr,
    degree_min=DEGREE_THR,
    degree_max=None,
    by_type=True,
    title=f"Nodes with degree ≥ {DEGREE_THR} ({SPACE})"
)

# --------------------------------------------------------------------------------------
# 8) BC (FACES ONLY) + TABLE + PLOTS
# --------------------------------------------------------------------------------------
print("\n=== BC faces (faces-only) ===")
bc_res = gaf.analyze_bc_faces(
    G,
    box=box,
    space=SPACE,
    coords_attr=coords_attr,
    eps=EPS_VOX,              # ALWAYS in vox; internally converted if SPACE="um"
    degree_thr=DEGREE_THR,
    return_node_ids=False
)

bc_df = gaf.bc_faces_table(bc_res, box_name="Box0")
print("\nBC table:\n", bc_df)

gaf.plot_bc_cube_net(
    bc_res,
    title=f"BC composition per face (space={SPACE})",
    show_unknown=False,
    show_high_degree=True
)

gaf.plot_bc_3_cubes_tinted(
    G,
    box,
    space=SPACE,
    coords_attr=coords_attr,
    eps=EPS_VOX
)


# --------------------------------------------------------------------------------------
# 9) GAIA-STYLE MICROSEGMENTS (density / volume fraction slabs) [requires atlas radii]
# --------------------------------------------------------------------------------------
if DO_GAIA:
    print("\n=== Gaia-style microsegments ===")
    ms = gaf.microsegments(data, space="um")
    gaf.count_microsegments_by_nkind(ms)

    # box must be µm for slabs
    if SPACE == "um":
        box_um = box
    else:
        box_um = gaf.make_box_in_um(center_vox=CENTER_VOX,box_size_um=BOX_SIZE_UM, res_um_per_vox=res_um_per_vox)

    try:
        slabs_df = gaf.vessel_vol_frac_slabs_in_box(ms, box_um, slab=SLAB_UM, axis=SLAB_AXIS)
        print("\nSlabs volume fraction:\n", slabs_df)
    except Exception as e:
        print("Slab density skipped (likely missing atlas radii):", e)


# --------------------------------------------------------------------------------------
# 10) REDUNDANCY 
# --------------------------------------------------------------------------------------
if DO_PATHS:
    #first k A→V shortest paths
    print("\n=== Simple A→V shortest paths (proxy) ===")
    paths_orig = gaf.av_paths_in_box(
        G,
        box=box,
        k=K_PATHS,
        space=SPACE,
        coords_attr=coords_attr,
        node_eps=0.0
    )
    print(f"Found {len(paths_orig)} paths (requested {K_PATHS}).")
    # plot paths in box
    if len(paths_orig):
        gaf.plot_av_paths_in_box(
        G, box,
        shortest_paths[:plot_paths_cap],
        space="um",
        coords_attr="coords_image_R",
        node_eps=0.0,
        title=f"Shortest A→V paths (sample) | {name}"
    )

print("\nAnalysis finished.")

# %%
# check differences radii and atlas 

import matplotlib.pyplot as plt

rv1 = data["vertex"]["radii"]
rv2 = data["vertex"]["radii_atlas"]

rg1 = data["geom"]["radii"]
rg2 = data["geom_R"]["radii_atlas_geom"]

fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Vertex - image radii
axes[0,0].hist(rv1, bins=60, alpha=0.7)
axes[0,0].set_title("Vertex radii (image space)")
axes[0,0].set_xlabel("Radius")
axes[0,0].set_ylabel("Count")

# Vertex - atlas radii
axes[0,1].hist(rv2, bins=60, alpha=0.7)
axes[0,1].set_title("Vertex radii_atlas")
axes[0,1].set_xlabel("Radius")
axes[0,1].set_ylabel("Count")

# Geometry - image radii
axes[1,0].hist(rg1, bins=60, alpha=0.7)
axes[1,0].set_title("Geom radii (image space)")
axes[1,0].set_xlabel("Radius")
axes[1,0].set_ylabel("Count")

# Geometry - atlas radii (µm)
axes[1,1].hist(rg2, bins=60, alpha=0.7)
axes[1,1].set_title("Geom radii_atlas_geom_R (µm)")
axes[1,1].set_xlabel("Radius (µm)")
axes[1,1].set_ylabel("Count")

fig.suptitle("Comparison of radii distributions", fontsize=16)
plt.tight_layout(rect=[0,0,1,0.95])
plt.show()
