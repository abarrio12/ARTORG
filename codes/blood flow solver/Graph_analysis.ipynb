# %% [markdown]
# # MVN DATA & ANALYTICS TASKS

# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# abre el archivo en modo lectura binaria
with open(r"C:\Users\Ana\OneDrive\Escritorio\ARTORG\igraph\MVN1_corrected_SI.pkl", "rb") as f:
    data = pickle.load(f)

# Ver tipo de objeto
print(type(data))

print(data.summary())
# Out:
# C:\Users\Ana\AppData\Local\Temp\ipykernel_8708\91526609.py:7: DeprecationWarning: numpy.core.numeric is deprecated and has been renamed to numpy._core.numeric. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numeric._frombuffer.
#   data = pickle.load(f)
# <class 'igraph.Graph'>
# IGRAPH U--- 9168 12071 --
# + attr: border_vertices (v), boundaryType (v), boundaryValue (v), coords (v), index (v), pBC (v), pressure (v), connectivity (e), diameter (e), diameters (e), htt (e), length (e), lengths (e), lengths2 (e), nkind (e), points (e)

# %% [markdown]
# ## 1) SINGLE CONNECTED COMPONENT

# %%
print(data.is_connected())

if data.is_connected():
    print("The graph is a single connected component")
else:
    print("The graph has more than one component")
    
components = data.components()  # returns a VertexClustering object
print("Number of connected components:", len(components))

# Useful for detecting isolated nodes or unconnected subsets 
for i, comp in enumerate(components):
    print(f"Component {i} has {len(comp)} nodes")
# Out:
# True
# The graph is a single connected component
# Number of connected components: 1
# Component 0 has 9168 nodes

# %% [markdown]
# ## 2) EDGES FOR EACH NKIND

# %%
edge_types = data.es["nkind"]

# OPTION A: use sets to get unique types
unique_edge_types = set(edge_types)
print("Types of unique edges (option A):", unique_edge_types)

# OPTION B: use numpy to get unique types and counts
unique, counts = np.unique(edge_types, return_counts=True)
for i, n in zip(unique, counts):
    print(f"Type of edge: {i}, Count: {n}")
    
plt.bar(unique, counts)
plt.show()
# Out:
# Types of unique edges (option A): {0, 1, 2, 3, 4, 5}
# Type of edge: 0, Count: 20
# Type of edge: 1, Count: 54
# Type of edge: 2, Count: 129
# Type of edge: 3, Count: 232
# Type of edge: 4, Count: 11635
# Type of edge: 5, Count: 1

# %% [markdown]
# # 3) MEAN DIAMETER FOR EACH NKIND

# %%
import numpy as np
import matplotlib.pyplot as plt


print(data.es.attributes())
print(data.es["diameters"][:2])  # first edge diameters (array of 3 values)
print(data.es["diameter"][:2])   # first 2 edge diameters (mean value)

# OPTION A: use diameters array and compute mean for each edge
diam_edge = np.array([np.mean(d) for d in data.es["diameters"]])

# classify by nkind
nkind = np.array(data.es["nkind"])

for k in np.unique(nkind):
    mean_d = diam_edge[nkind == k].mean()
    print(f"OPTION A: nkind = {k}: average diameter = {mean_d:.6e}")

# OPTION B: use diameter attribute directly
diam_edge_att = np.array(data.es["diameter"])
for k in np.unique(nkind):
    mean_d = diam_edge_att[nkind == k].mean()
    print(f"OPTION B: nkind = {k}: average diameter (att) = {mean_d:.6e}")

# --- Plot ---
unique_k = np.unique(nkind)
mean_a = [diam_edge[nkind == k].mean() for k in unique_k]
mean_b = [diam_edge_att[nkind == k].mean() for k in unique_k]

x = np.arange(len(unique_k))
width = 0.35

plt.bar(x - width/2, mean_a, width, label='OPTION A')
plt.bar(x + width/2, mean_b, width, label='OPTION B')

plt.xticks(x, unique_k)
plt.xlabel("nkind")
plt.ylabel("Average diameter")
plt.title("Average edge diameter by nkind")
plt.legend()
plt.show()

# Error
mean_error = np.mean(np.abs(diam_edge - diam_edge_att))
print(f"Error promedio: {mean_error:.2e}")
# Out:
# ['diameters', 'htt', 'nkind', 'lengths', 'diameter', 'connectivity', 'length', 'points', 'lengths2']
# [array([5.52154171e-06, 5.52154171e-06, 5.52154171e-06]), array([3.14983642e-06, 3.14983642e-06, 3.14983642e-06])]
# [np.float64(5.5215417147e-06), np.float64(3.1498364209999998e-06)]
# OPTION A: nkind = 0: average diameter = 2.015844e-05
# OPTION A: nkind = 1: average diameter = 2.909457e-05
# OPTION A: nkind = 2: average diameter = 6.884343e-06
# OPTION A: nkind = 3: average diameter = 7.746774e-06
# OPTION A: nkind = 4: average diameter = 3.990220e-06
# OPTION A: nkind = 5: average diameter = 8.300136e-06
# OPTION B: nkind = 0: average diameter (att) = 2.018907e-05
# OPTION B: nkind = 1: average diameter (att) = 2.936807e-05
# OPTION B: nkind = 2: average diameter (att) = 6.921574e-06
# OPTION B: nkind = 3: average diameter (att) = 7.782175e-06
# OPTION B: nkind = 4: average diameter (att) = 3.994613e-06
# OPTION B: nkind = 5: average diameter (att) = 9.055386e-06
# Error promedio: 2.84e-08

# %% [markdown]
# # 4) Average length for each vessel type

# %%
import numpy as np
import matplotlib.pyplot as plt


print(data.es["lengths"][:2])  # first length arrays (3 numbers per edge)
print(data.es["length"][:2])   # first 2 mean lengths

# OPTION A: use lengths array and compute total length for each edge
lengths_edges = np.array([np.sum(l) for l in data.es["lengths"]])

# classify by nkind
nkind = np.array(data.es["nkind"])

for k in np.unique(nkind):
    mean_l = lengths_edges[nkind == k].mean()
    print(f"OPTION A: nkind = {k}: average length = {mean_l:.6e}")

# OPTION B: use length attribute directly
lengths_att = np.array(data.es["length"])
for k in np.unique(nkind):
    mean_l = lengths_att[nkind == k].mean()
    print(f"OPTION B: nkind = {k}: average length (att) = {mean_l:.6e}")

# Plot
unique_k = np.unique(nkind)
mean_a = [lengths_edges[nkind == k].mean() for k in unique_k]
mean_b = [lengths_att[nkind == k].mean() for k in unique_k]

x = np.arange(len(unique_k))
width = 0.35

plt.bar(x - width/2, mean_a, width, label='OPTION A')
plt.bar(x + width/2, mean_b, width, label='OPTION B')

# To show in scientific notation
plt.ticklabel_format(style='sci', axis='y', scilimits=(0,0))

plt.xticks(x, unique_k)
plt.xlabel("nkind")
plt.ylabel("Average length")
plt.title("Average edge length by nkind")
plt.legend()
plt.show()

# Mean error
mean_error_length = np.mean(np.abs(lengths_edges - lengths_att))
print(f"Error in lenghts: {mean_error_length:.2e}")
# Out:
# [array([8.54822138e-06, 8.54822138e-06, 8.54822138e-06]), array([6.28825577e-06, 6.28825577e-06, 6.28825577e-06])]
# [np.float64(2.5644664139996576e-05), np.float64(1.886476730802158e-05)]
# OPTION A: nkind = 0: average length = 1.763233e-04
# OPTION A: nkind = 1: average length = 7.762322e-05
# OPTION A: nkind = 2: average length = 8.145240e-05
# OPTION A: nkind = 3: average length = 4.699330e-05
# OPTION A: nkind = 4: average length = 6.841229e-05
# OPTION A: nkind = 5: average length = 7.974691e-06
# OPTION B: nkind = 0: average length (att) = 1.763233e-04
# OPTION B: nkind = 1: average length (att) = 7.762322e-05
# OPTION B: nkind = 2: average length (att) = 8.145240e-05
# OPTION B: nkind = 3: average length (att) = 4.699330e-05
# OPTION B: nkind = 4: average length (att) = 6.841650e-05
# OPTION B: nkind = 5: average length (att) = 7.974691e-06
# Error in lenghts: 4.05e-09

# %% [markdown]
# # 5) Degrees of the nodes? Are there nodes with degree > 3?

# %%
degrees = np.array(data.degree())
print("Degrees of nodes:", np.unique(degrees))

count = 0
for i, d in enumerate(degrees):
    if d > 3:
        print(f"Node {i} has degree {d}")
        count += 1
       
print(count)


# Histogram of degrees
plt.figure(figsize=(8,5))
plt.hist(degrees, bins=np.arange(degrees.min(), degrees.max()+2)-0.5, color='skyblue', edgecolor='k')
plt.xlabel("Degree of node")
plt.ylabel("Number of nodes")
plt.title("Distribution of node degrees")

# Nodes with degree > 3 highlighted in another color
plt.hist(degrees[degrees > 3], bins=np.arange(degrees.min(), degrees.max()+2)-0.5, 
         color='salmon', edgecolor='k', label='Degree > 3')

plt.legend()
plt.xticks(np.arange(degrees.min(), degrees.max()+1))
plt.show()
# Out:
# Degrees of nodes: [1 2 3 4]
# Node 0 has degree 4
# Node 28 has degree 4
# Node 42 has degree 4
# Node 48 has degree 4
# Node 49 has degree 4
# Node 51 has degree 4
# Node 58 has degree 4
# Node 59 has degree 4
# Node 65 has degree 4
# Node 68 has degree 4
# Node 73 has degree 4
# Node 76 has degree 4
# Node 77 has degree 4
# Node 82 has degree 4
# Node 83 has degree 4
# Node 102 has degree 4
# Node 107 has degree 4
# Node 124 has degree 4
# Node 129 has degree 4
# Node 148 has degree 4
# Node 149 has degree 4
# Node 151 has degree 4
# Node 155 has degree 4
# Node 194 has degree 4
# Node 197 has degree 4
# Node 201 has degree 4
# Node 209 has degree 4
# Node 214 has degree 4
# Node 237 has degree 4
# Node 246 has degree 4
# Node 253 has degree 4
# Node 287 has degree 4
# Node 306 has degree 4
# Node 307 has degree 4
# Node 332 has degree 4
# Node 336 has degree 4
# Node 345 has degree 4
# Node 354 has degree 4
# Node 357 has degree 4
# Node 367 has degree 4
# Node 374 has degree 4
# Node 377 has degree 4
# Node 407 has degree 4
# Node 415 has degree 4
# Node 417 has degree 4
# Node 445 has degree 4
# Node 470 has degree 4
# Node 507 has degree 4
# Node 510 has degree 4
# Node 519 has degree 4
# Node 522 has degree 4
# Node 576 has degree 4
# Node 608 has degree 4
# Node 620 has degree 4
# Node 658 has degree 4
# Node 669 has degree 4
# Node 689 has degree 4
# Node 703 has degree 4
# Node 751 has degree 4
# Node 789 has degree 4
# Node 790 has degree 4
# Node 793 has degree 4
# Node 818 has degree 4
# Node 820 has degree 4
# Node 850 has degree 4
# Node 862 has degree 4
# Node 894 has degree 4
# Node 925 has degree 4
# Node 930 has degree 4
# Node 932 has degree 4
# Node 973 has degree 4
# Node 975 has degree 4
# Node 997 has degree 4
# Node 1013 has degree 4
# Node 1029 has degree 4
# Node 1035 has degree 4
# Node 1126 has degree 4
# Node 1161 has degree 4
# Node 1167 has degree 4
# Node 1171 has degree 4
# Node 1243 has degree 4
# Node 1250 has degree 4
# Node 1288 has degree 4
# Node 1289 has degree 4
# Node 1296 has degree 4
# Node 1300 has degree 4
# Node 1318 has degree 4
# Node 1321 has degree 4
# Node 1328 has degree 4
# Node 1351 has degree 4
# Node 1408 has degree 4
# Node 1417 has degree 4
# Node 1422 has degree 4
# Node 1428 has degree 4
# Node 1431 has degree 4
# Node 1459 has degree 4
# Node 1512 has degree 4
# Node 1513 has degree 4
# Node 1528 has degree 4
# Node 1538 has degree 4
# Node 1542 has degree 4
# Node 1550 has degree 4
# Node 1555 has degree 4
# Node 1571 has degree 4
# Node 1589 has degree 4
# Node 1603 has degree 4
# Node 1605 has degree 4
# Node 1641 has degree 4
# Node 1645 has degree 4
# Node 1648 has degree 4
# Node 1678 has degree 4
# Node 1698 has degree 4
# Node 1706 has degree 4
# Node 1710 has degree 4
# Node 1750 has degree 4
# Node 1760 has degree 4
# Node 1791 has degree 4
# Node 1883 has degree 4
# Node 1938 has degree 4
# Node 1958 has degree 4
# Node 1970 has degree 4
# Node 1993 has degree 4
# Node 2001 has degree 4
# Node 2113 has degree 4
# Node 2138 has degree 4
# Node 2198 has degree 4
# Node 2234 has degree 4
# Node 2293 has degree 4
# Node 2317 has degree 4
# Node 2370 has degree 4
# Node 2374 has degree 4
# Node 2391 has degree 4
# Node 2395 has degree 4
# Node 2404 has degree 4
# Node 2433 has degree 4
# Node 2443 has degree 4
# Node 2459 has degree 4
# Node 2479 has degree 4
# Node 2481 has degree 4
# Node 2482 has degree 4
# Node 2521 has degree 4
# Node 2564 has degree 4
# Node 2571 has degree 4
# Node 2606 has degree 4
# Node 2615 has degree 4
# Node 2680 has degree 4
# Node 2726 has degree 4
# Node 2729 has degree 4
# Node 2772 has degree 4
# Node 2804 has degree 4
# Node 2823 has degree 4
# Node 2836 has degree 4
# Node 2845 has degree 4
# Node 2851 has degree 4
# Node 2892 has degree 4
# Node 2900 has degree 4
# Node 2920 has degree 4
# Node 2944 has degree 4
# Node 2970 has degree 4
# Node 2983 has degree 4
# Node 2994 has degree 4
# Node 2998 has degree 4
# Node 3026 has degree 4
# Node 3033 has degree 4
# Node 3052 has degree 4
# Node 3053 has degree 4
# Node 3072 has degree 4
# Node 3085 has degree 4
# Node 3086 has degree 4
# Node 3099 has degree 4
# Node 3103 has degree 4
# Node 3104 has degree 4
# Node 3110 has degree 4
# Node 3138 has degree 4
# Node 3170 has degree 4
# Node 3195 has degree 4
# Node 3196 has degree 4
# Node 3208 has degree 4
# Node 3263 has degree 4
# Node 3296 has degree 4
# Node 3315 has degree 4
# Node 3317 has degree 4
# Node 3318 has degree 4
# Node 3322 has degree 4
# Node 3328 has degree 4
# Node 3337 has degree 4
# Node 3349 has degree 4
# Node 3384 has degree 4
# Node 3401 has degree 4
# Node 3417 has degree 4
# Node 3464 has degree 4
# Node 3465 has degree 4
# Node 3527 has degree 4
# Node 3555 has degree 4
# Node 3577 has degree 4
# Node 3586 has degree 4
# Node 3619 has degree 4
# Node 3640 has degree 4
# Node 3673 has degree 4
# Node 3732 has degree 4
# Node 3734 has degree 4
# Node 3739 has degree 4
# Node 3767 has degree 4
# Node 3768 has degree 4
# Node 3772 has degree 4
# Node 3786 has degree 4
# Node 3862 has degree 4
# Node 3884 has degree 4
# Node 3886 has degree 4
# Node 3893 has degree 4
# Node 3917 has degree 4
# Node 3918 has degree 4
# Node 3934 has degree 4
# Node 3977 has degree 4
# Node 4001 has degree 4
# Node 4018 has degree 4
# Node 4025 has degree 4
# Node 4050 has degree 4
# Node 4064 has degree 4
# Node 4070 has degree 4
# Node 4080 has degree 4
# Node 4081 has degree 4
# Node 4087 has degree 4
# Node 4092 has degree 4
# Node 4106 has degree 4
# Node 4115 has degree 4
# Node 4158 has degree 4
# Node 4174 has degree 4
# Node 4178 has degree 4
# Node 4192 has degree 4
# Node 4213 has degree 4
# Node 4217 has degree 4
# Node 4241 has degree 4
# Node 4245 has degree 4
# Node 4277 has degree 4
# Node 4313 has degree 4
# Node 4327 has degree 4
# Node 4341 has degree 4
# Node 4342 has degree 4
# Node 4392 has degree 4
# Node 4417 has degree 4
# Node 4434 has degree 4
# Node 4444 has degree 4
# Node 4450 has degree 4
# Node 4454 has degree 4
# Node 4491 has degree 4
# Node 4530 has degree 4
# Node 4566 has degree 4
# Node 4657 has degree 4
# Node 4686 has degree 4
# Node 4703 has degree 4
# Node 4729 has degree 4
# Node 4758 has degree 4
# Node 4788 has degree 4
# Node 4808 has degree 4
# Node 4837 has degree 4
# Node 4892 has degree 4
# Node 4911 has degree 4
# Node 4920 has degree 4
# Node 4949 has degree 4
# Node 4969 has degree 4
# Node 4981 has degree 4
# Node 5023 has degree 4
# Node 5027 has degree 4
# Node 5030 has degree 4
# Node 5061 has degree 4
# Node 5070 has degree 4
# Node 5078 has degree 4
# Node 5180 has degree 4
# Node 5196 has degree 4
# Node 5209 has degree 4
# Node 5223 has degree 4
# Node 5230 has degree 4
# Node 5270 has degree 4
# Node 5276 has degree 4
# Node 5279 has degree 4
# Node 5287 has degree 4
# Node 5295 has degree 4
# Node 5315 has degree 4
# Node 5332 has degree 4
# Node 5344 has degree 4
# Node 5373 has degree 4
# Node 5415 has degree 4
# Node 5449 has degree 4
# Node 5466 has degree 4
# Node 5478 has degree 4
# Node 5511 has degree 4
# Node 5514 has degree 4
# Node 5586 has degree 4
# Node 5594 has degree 4
# Node 5610 has degree 4
# Node 5677 has degree 4
# Node 5714 has degree 4
# Node 5719 has degree 4
# Node 5720 has degree 4
# Node 5731 has degree 4
# Node 5748 has degree 4
# Node 5749 has degree 4
# Node 5750 has degree 4
# Node 5758 has degree 4
# Node 5828 has degree 4
# Node 5855 has degree 4
# Node 5880 has degree 4
# Node 5889 has degree 4
# Node 5953 has degree 4
# Node 5963 has degree 4
# Node 5986 has degree 4
# Node 6042 has degree 4
# Node 6115 has degree 4
# Node 6186 has degree 4
# Node 6187 has degree 4
# Node 6198 has degree 4
# Node 6201 has degree 4
# Node 6219 has degree 4
# Node 6239 has degree 4
# Node 6240 has degree 4
# Node 6315 has degree 4
# Node 6317 has degree 4
# Node 6356 has degree 4
# Node 6398 has degree 4
# Node 6420 has degree 4
# Node 6534 has degree 4
# Node 6549 has degree 4
# Node 6550 has degree 4
# Node 6551 has degree 4
# Node 6552 has degree 4
# Node 6553 has degree 4
# Node 6554 has degree 4
# Node 6555 has degree 4
# Node 6556 has degree 4
# Node 6557 has degree 4
# Node 6558 has degree 4
# Node 6559 has degree 4
# Node 6560 has degree 4
# Node 6561 has degree 4
# Node 6562 has degree 4
# Node 6563 has degree 4
# Node 6564 has degree 4
# Node 6565 has degree 4
# Node 6566 has degree 4
# Node 6567 has degree 4
# Node 6569 has degree 4
# Node 6570 has degree 4
# Node 6571 has degree 4
# Node 6572 has degree 4
# Node 6573 has degree 4
# Node 6574 has degree 4
# Node 6576 has degree 4
# Node 6577 has degree 4
# Node 6578 has degree 4
# Node 6579 has degree 4
# Node 6580 has degree 4
# Node 6581 has degree 4
# Node 6582 has degree 4
# Node 6583 has degree 4
# Node 6584 has degree 4
# Node 6585 has degree 4
# Node 6586 has degree 4
# Node 6587 has degree 4
# Node 6588 has degree 4
# Node 6589 has degree 4
# Node 6590 has degree 4
# Node 6591 has degree 4
# Node 6592 has degree 4
# Node 6593 has degree 4
# Node 6594 has degree 4
# Node 6595 has degree 4
# Node 6596 has degree 4
# Node 6597 has degree 4
# Node 6598 has degree 4
# Node 6599 has degree 4
# Node 6600 has degree 4
# Node 6601 has degree 4
# Node 6602 has degree 4
# Node 6603 has degree 4
# Node 6604 has degree 4
# Node 6605 has degree 4
# Node 6606 has degree 4
# Node 6607 has degree 4
# Node 6608 has degree 4
# Node 6609 has degree 4
# Node 6610 has degree 4
# Node 6611 has degree 4
# Node 6612 has degree 4
# Node 6613 has degree 4
# Node 6615 has degree 4
# Node 6616 has degree 4
# Node 6617 has degree 4
# Node 6618 has degree 4
# Node 6619 has degree 4
# Node 6620 has degree 4
# Node 6621 has degree 4
# Node 6622 has degree 4
# Node 6623 has degree 4
# Node 6624 has degree 4
# Node 6625 has degree 4
# Node 6626 has degree 4
# Node 6627 has degree 4
# Node 6628 has degree 4
# Node 6629 has degree 4
# Node 6630 has degree 4
# Node 6631 has degree 4
# Node 6632 has degree 4
# Node 6633 has degree 4
# Node 6634 has degree 4
# Node 6635 has degree 4
# Node 6636 has degree 4
# Node 6637 has degree 4
# Node 6638 has degree 4
# Node 6639 has degree 4
# Node 6640 has degree 4
# Node 6641 has degree 4
# Node 6642 has degree 4
# Node 6643 has degree 4
# Node 6644 has degree 4
# Node 6645 has degree 4
# Node 6646 has degree 4
# Node 6647 has degree 4
# Node 6648 has degree 4
# Node 6649 has degree 4
# Node 6650 has degree 4
# Node 6651 has degree 4
# Node 6652 has degree 4
# Node 6653 has degree 4
# Node 6654 has degree 4
# Node 6655 has degree 4
# Node 6656 has degree 4
# Node 6657 has degree 4
# Node 6658 has degree 4
# Node 6659 has degree 4
# Node 6660 has degree 4
# Node 6661 has degree 4
# Node 6662 has degree 4
# Node 6663 has degree 4
# Node 6664 has degree 4
# Node 6665 has degree 4
# Node 6666 has degree 4
# Node 6667 has degree 4
# Node 6668 has degree 4
# Node 6687 has degree 4
# Node 6697 has degree 4
# 441

# %% [markdown]
# # 6) Nodes with boundary conditions compared to the total number of nodes and location

# %%
print(data.vs.attributes()) # we have border vertices, boundary type and boundary value to check BCs
print(data.vs["border_vertices"][:10])  # first 10 entries
print(data.vs["boundaryType"][:10])  # first 10 entries

# OPTION A: check by frontier nodes (always will have a BC if frontier)
frontier_nodes = np.array([fn is not None for fn in data.vs["border_vertices"]])

# OPTION B: check by boundaryType
# booleano de nodos con boundaryType definido (no None)
has_boundary = np.array([bt is not None for bt in data.vs["boundaryType"]])

# OPTION C: check by boundaryValue

# no need to check compliance of both (with 1 is sufficient)
node_with_bc = frontier_nodes & has_boundary

print(f"Nodes with BC: {np.sum(node_with_bc)} of {len(data.vs)}")
# location in the array
print(f"Location of nodes with BC: {np.where(node_with_bc)[0]}")
# get coordinates of these nodes
coords_with_bc = np.array(data.vs["coords"])[node_with_bc]
print("Coordinates of nodes with BC:", coords_with_bc[:5])

coords_all = np.array(data.vs["coords"])
# Out:
# ['index', 'coords', 'pBC', 'pressure', 'border_vertices', 'boundaryType', 'boundaryValue']
# [None, None, None, None, 1, None, None, None, None, None]
# [None, None, None, None, 1, None, None, None, None, None]
# Nodes with BC: 1275 of 9168
# Location of nodes with BC: [   4   93  103 ... 9165 9166 9167]
# Coordinates of nodes with BC: [[ 1.87309433e-03  1.56175702e-03 -6.12222222e-05]
#  [ 1.75309433e-03  2.28675702e-03 -3.62222222e-05]
#  [ 8.66094333e-04  1.62975702e-03 -3.42222222e-05]
#  [ 1.30409433e-03  2.24675702e-03 -2.92222222e-05]
#  [ 8.23094333e-04  1.74675702e-03 -2.62222222e-05]]

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection='3d')

# All nodes in light gray
ax.scatter(coords_all[:,0], coords_all[:,1], coords_all[:,2], color='lightgray', s=10, alpha=0.1)

# Nodes BC in red
ax.scatter(coords_with_bc[:,0], coords_with_bc[:,1], coords_with_bc[:,2], color='red', s=50, alpha=0.8, label='Nodes with BC')

ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
ax.set_title("Nodes with Boundary Conditions (3D)")
ax.legend()
plt.show()

# %%
import numpy as np

count_bc = np.sum(node_with_bc)
count_all = len(node_with_bc)

plt.bar(['Normal nodes','Nodes with BC'], [count_all - count_bc, count_bc], color=['lightgray','red'])
plt.ylabel('Number of nodes')
plt.title('Nodes with and without BC')
plt.show()
